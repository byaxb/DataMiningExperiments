# %%
import feather

# %%
ano_detect_train = feather.read_dataframe("D://desktop/In-class contest2/ano_detect_train2.feather")

# %%
ano_detect_train.head()
# Out:
#    timestamp        x1        x2    x3        x4        x5        x6 x7  \
# 0         54 -0.406190  0.550000  1.00  0.998154  0.539320  1.381340  4
# 1         89  0.916423  0.032787  0.00 -0.460069  0.750830  0.049665  4
# 2         15 -0.567527  0.080000  0.20  0.139726  0.342592  0.144756  4
# 3         63 -0.249668  0.333333  0.75  0.379598  0.416503  0.667622  3
# 4         75  0.538768  0.038462  1.00  0.574191  0.394564  0.147207  3
#
#          x8        x9  ...       x58       x59  x60       x61  x62  x63   x64  \
# 0  1.310345  0.000000  ...  1.166665  0.000000  221  0.900000  1.0    3  1.00
# 1  0.030638  0.333333  ...  0.041754  0.363622  210  0.649485  0.0    1  0.00
# 2  0.091437  0.210526  ...  0.114698  0.032530  212  0.465517  0.2    2  0.20
# 3  0.686788  0.333333  ...  0.572710  0.360629  216  0.273973  1.0    2  0.75
# 4  0.129822  0.073171  ...  0.220971  0.076487  211  0.473684  1.0    3  1.00
#
#         x65       x66  y_label
# 0  1.166665  1.310345   normal
# ...

# %%
ano_detect_train.shape
# Out:
# (104532, 68)

# %%
ano_detect_test = feather.read_dataframe("D://desktop/In-class contest2/ano_detect_test2.feather")

# %%
ano_detect_test
# Out:
#        timestamp        x1        x2        x3        x4        x5        x6  \
# 0            163  0.450394       inf  0.214286  0.976268  0.480289  1.167811
# 1             95  0.566660  0.062500  0.000000  0.941472  0.161229  0.123323
# 2            204  1.485823  0.285714  0.000000  0.662313  0.062314  0.670646
# 3             76  0.111283  0.000000  0.285714  0.718520  0.380065  0.178316
# 4            117  0.546859  0.021978  1.000000  0.987409  0.995944  0.087974
# ...          ...       ...       ...       ...       ...       ...       ...
# 44795         95  1.006966  0.041667  0.000000 -0.157802  0.381224  0.126328
# 44796         37  0.145671  0.000000  1.000000  0.576591  1.000000  0.073663
# 44797         14 -0.357565  0.136364  0.100000 -0.231902  0.651254  0.096888
# 44798         47  0.000000  0.275862  0.166667  0.360178  0.600559  0.164721
# 44799        115  0.564971  0.214286  0.100000  0.995293  0.551691  0.262083
#
# ...

# %%
ano_detect_test.shape
# Out:
# (44800, 67)

# %%
ano_detect_test.describe()
# Out:
#           timestamp            x1            x2            x3            x4  \
# count  44800.000000  44800.000000  4.480000e+04  44800.000000  44800.000000
# mean      80.086473      0.297884           inf      0.419818      0.578248
# std       52.039272      1.091338           NaN      0.406560      0.462671
# min        9.000000     -2.866365  0.000000e+00      0.000000     -1.000000
# 25%       37.000000     -0.336458  5.263158e-02      0.032258      0.368023
# 50%       75.000000      0.000000  1.333333e-01      0.258065      0.761712
# 75%      106.000000      0.654525  2.962963e-01      1.000000      0.930467
# max      220.000000     18.330383           inf      1.000000      1.000000
#
#                  x5            x6            x8            x9           x10  \
# count  44800.000000  44800.000000  44800.000000  44800.000000  44800.000000
# mean       0.514675      0.343634      0.322357      0.341806      0.514671
# ...
